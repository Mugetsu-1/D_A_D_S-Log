# %% [markdown]
# Feature Extraction is the process of selecting and extracting the most important features from raw data.

# %% [markdown]
# ML Application --> 1000 features --> Most Important Features --> Train using ML algorithm

# %% [markdown]
# 1) Feature Scaling

# %% [markdown]
# | Age (y) | Weight (kg) | Height (cm) | BMI  |
# |---------|-------------|-------------|------|
# | 32      | 70          | 140         |   _  |
# | 28      | 75          | 160         |   _  |
# | 35      | 80          | 155         |    _ |

# %% [markdown]
# Scale down big numbers within some range.

# %% [markdown]
# Standardization => Mainlu used in ML Algorithms

# %% [markdown]
# Z-score (Mean = 0 and SD = 1)

# %% [markdown]
# Normalization => Mainly used in Deep Learning

# %% [markdown]
# Scale down in range of minimum and maximum.

# %% [markdown]
# 2) Feature Selection
# - We just pick the most important features.

# %% [markdown]
# 500 features --> Top 10 features --> Train ML Model
