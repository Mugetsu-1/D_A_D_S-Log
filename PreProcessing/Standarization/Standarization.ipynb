# %%
import seaborn as sns # import the seaborn library

# %%
df = sns.load_dataset('tips') # load the tips dataset from seaborn

# %%
df.head() # display the first 5 rows of the dataset

# %%
df.shape

# %%
df['size'].unique()

# %%
max(df['total_bill'].unique())

# %%
min(df['total_bill'].unique())

# %%
df['total_bill'] # display the total_bill column

# %%
max(df['total_bill'])

# %%
min(df['total_bill'])

# %%
list(df['total_bill']) # display the total_bill column as a list

# %%
total_bill = list(df['total_bill']) # assign the total_bill column to a variable called total_bill

# %%
import numpy as np # import the numpy library
mean = np.mean(total_bill) # calculate the mean of the total_bill column
std = np.std(total_bill) # calculate the standard deviation of the total_bill column

# %%
mean, std # display the mean and standard deviation

# %%
normalized_data = [] # create an empty list called normalized_data
for i in total_bill: # loop through the total_bill column
    z_score = (i - mean) / std # calculate the z-score
    normalized_data.append(z_score) # append the z-score to the normalized_data list

# %%
normalized_data # display the normalized_data list

# %%
max(normalized_data) # display the maximum value in the normalized_data list

# %%
min(normalized_data) # display the minimum value in the normalized_data list

# %%
print(normalized_data) # display the normalized_data list

# %%
sns.histplot(total_bill, kde=True) # create a histogram of the total_bill column

# %%
sns.histplot(normalized_data, kde=True) # create a histogram of the normalized_data list

# %%
# %pip install scikit-learn

# %%
from sklearn.preprocessing import StandardScaler # import the StandardScaler class from the sklearn.preprocessing module

# %%
scaler = StandardScaler() # create an instance of the StandardScaler class

# %%
scaler

# %%
df.head() # display the first 5 rows of the dataset

# %%
scaler.fit(df[['total_bill','tip']]) # fit the StandardScaler to the total_bill and tip columns

# %%
df[['total_bill','tip']]

# %%
data = scaler.transform(df[['total_bill','tip']]) # transform the total_bill and tip columns

# %%
import pandas as pd
df = pd.DataFrame(scaler.fit_transform(df[['total_bill','tip']]), columns=['total_bill_standard','tip_standard']) # create a DataFrame of the transformed data
df.head()

# %%
max(df['total_bill_standard']) # display the maximum value in the total_bill column

# %%
min(df['total_bill_standard']) # display the minimum value in the total_bill column

# %%
max(df['tip_standard']) # display the maximum value in the tip column

# %%
min(df['tip_standard']) # display the minimum value in the tip column

# %%
df['total_bill_standard'].mean()

# %%
df['total_bill_standard'].std()
