# %%
import requests
from bs4 import BeautifulSoup

# %%
web = requests.get("https://tutorialsfreak.com/")
print(web)

# %%
soup = BeautifulSoup(web.content, "html.parser")

# %%
print(soup.prettify())

# %%
soup.title

# %%
soup.p

# %%
soup.a

# %%
soup.title.name

# %%
soup.h1

# %%
tags = soup.html
print(tags)

# %%
print(tags.a)

# %%
print(tags.p)

# %%
print(tags.h2)

# %%
print(tags.h2.string)

# %%
print(tags.h2.text)

# %%
soup.head

# %%
soup.title

# %%
soup.find("p")

# %%
soup.find_all("p")

# %%
body = soup.body
body

# %%
all_divs = body.find_all("div", class_= "card-haed")
all_divs

# %%
for div in all_divs:
  print(div.find("h3").text)
  print(div.find("ul").text)

# %% [markdown]
# ### Collecting all the links from a website

# %%
links = soup.find_all("a")

# %%
for link in links:
  print(link.get("href"))

# %% [markdown]
# ### Extracting images from the website

# %%
images = soup.find_all("img")
for img in images:
  print(img.get("src"))
