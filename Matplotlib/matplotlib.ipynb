#         1.40727327e+00,  1.56858645e+00,  1.75753145e+00,  1.98311795e+00,
#         2.25868898e+00,  2.60489204e+00,  3.05548254e+00,  3.66970398e+00,
#         4.56196593e+00,  5.98557623e+00,  8.63545362e+00,  1.53541991e+01,
#         6.76281970e+01, -2.81845121e+01, -1.16377302e+01, -7.30928682e+00,
#        -5.30779352e+00, -4.14973606e+00, -3.39159840e+00, -2.85441160e+00,
#        -2.45209815e+00, -2.13812112e+00, -1.88511404e+00, -1.67592719e+00,
#        -1.49926309e+00, -1.34737307e+00, -1.21476205e+00, -1.09742174e+00,
#        -9.92356718e-01, -8.97280575e-01, -8.10415002e-01, -7.30353170e-01,
#        -6.55964622e-01, -5.86327597e-01, -5.20679918e-01, -4.58382714e-01,
#        -3.98893148e-01, -3.41743569e-01, -2.86525315e-01, -2.32875886e-01,
#        -1.80468610e-01, -1.29004118e-01, -7.82031331e-02, -2.78001946e-02,
#         2.24619967e-02,  7.28378782e-02,  1.23584199e-01,  1.74965291e-01,
#         2.27258682e-01,  2.80761284e-01,  3.35796493e-01,  3.92722551e-01,
#         4.51942662e-01,  5.13917513e-01,  5.79181064e-01,  6.48360827e-01])

# %%
plt.plot(x,y,'-k')
# plt.plot gives line graph

# %% [markdown]
# Line Styles in Matplotlib
# Here are the main line styles:
#
# '-' → Solid line (default).
#
# '--' → Dashed line.
#
# '-.' → Dash-dot line.
#
# ':' → Dotted line.
#
# '' → No line (use markers only).
#
# Colors
# You can use single-letter color codes:
#
# 'b' = blue
#
# 'g' = green
#
# 'r' = red
#
# 'c' = cyan
#
# 'm' = magenta
#
# 'y' = yellow
#
# 'k' = black
#
# 'w' = white

# %%
# plt.plot(x,y, linestyle='-', color='red')
plt.plot(x,y,'-y')
plt.xlabel('this is my x data')
plt.ylabel('this is my y data')
plt.title('This is my title')
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y)

# %%
x
# Out:
# array([0.27960078, 0.58032255, 0.78088915, 0.16846371, 0.53713035,
#        0.47495114, 0.18219289, 0.54141159, 0.26605389, 0.71464983,
#        0.30165795, 0.13051148, 0.16115975, 0.0718304 , 0.65569596,
#        0.56123619, 0.53691091, 0.03430701, 0.92771156, 0.81476079,
#        0.84913138, 0.99914885, 0.77999491, 0.99159203, 0.9189127 ,
#        0.49488377, 0.99597598, 0.01392649, 0.49806426, 0.49930944,
#        0.50102215, 0.23146838, 0.22654815, 0.99405182, 0.49130568,
#        0.41496982, 0.12478996, 0.23911757, 0.61406335, 0.05773658,
#        0.44399376, 0.78329751, 0.08908792, 0.62052949, 0.01228161,
#        0.58219655, 0.06725162, 0.99211432, 0.59949106, 0.25887515])

# %%
y
# Out:
# array([0.44898951, 0.40161738, 0.76468312, 0.67087585, 0.31039898,
#        0.74832032, 0.49525697, 0.3578789 , 0.47201612, 0.07951028,
#        0.66068055, 0.56772802, 0.28721421, 0.57239122, 0.25458378,
#        0.67263612, 0.7880717 , 0.7882647 , 0.80964067, 0.20985171,
#        0.805967  , 0.38108042, 0.56342705, 0.07527294, 0.60115791,
#        0.81009329, 0.5273404 , 0.66697697, 0.42849247, 0.54304749,
#        0.20800974, 0.92009029, 0.35149504, 0.60826586, 0.63738966,
#        0.79249826, 0.24140888, 0.09617525, 0.34416047, 0.13487473,
#        0.99017571, 0.43601462, 0.82368989, 0.06387856, 0.25389265,
#        0.01482199, 0.19562328, 0.87294087, 0.3105741 , 0.36884985])

# %%
colours = np.random.rand(50) # Generates 50 random values between 0 and 1 and maps to the respective colours.
sizes = 1000 * np.random.rand(50) # Generates 50 random values between 0 and 1
plt.scatter(x,y,c = colours,cmap='viridis',s = sizes, alpha = 0.4) #c=colours: Assigns color values to each point. Matplotlib uses a colormap to map values (0 to 1) into colors.
# s=sizes: Sets the size of each point.
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Random Data')
# Out:
# Text(0.5, 1.0, 'Random Data')

# %% [markdown]
# To find colormaps of matplotlib, you can do
#
# plt.colormaps()

# %%
print(len(plt.colormaps()))
# Out:
# 180

# %%
x = ['a','b','c','d','e']

# %%
x = [5,6,7,8,9]
y = [10,11,12,13,14]
plt.scatter(x,y, c=np.random.rand(5), s=500)

# %%
y = np.random.rand(5) # generates random 5 data between 0 and 1
plt.bar(x,y) # Plots the bar graph from x-coordinates and y-coordinates
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Bar Plot')
plt.show()

# %%
y
# Out:
# array([0.22488229, 0.43675081, 0.87007801, 0.9830235 , 0.98014515])

# %%
plt.barh(x,y) # plt.barh(x, y) in Matplotlib is used to create a horizontal bar chart.
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Bar Plot')
# Out:
# Text(0.5, 1.0, 'Bar Plot')

# %%
plt.figure(figsize=(5,5)) # Determines the figure size of the chart in inches. The first is for x-axis and second is for y-axis
plt.plot(x,y,'--r') # Creates a Line graph
plt.xlabel('this is my x data')
plt.ylabel('this is my y data')
plt.title('This is my title')
plt.grid() # Shows the grid
plt.show()

# %%
#x = np.random.rand(50)
#y = np.random.rand(50)
x = [1,2,3,4,5]
y=[5,6,7,8,9]
colours = np.random.rand(5)
sizes = 1000 * np.random.rand(5)
plt.scatter(x,y,c = colours,s = sizes, alpha = .5, marker = 'o') # creates a scatter plot. Using marker = "" defines the marker in the plot
#plt.scatter(x,y,c = '#A6D13F',s = sizes, alpha = .5)
#plt.scatter(x,y,c = colours,s = sizes, alpha = .5)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Random Data')

# %%
x = [4,5,6,7,8,9,10,12] # Shows positive correlation. That means value of y is increasing when x is increasing
y = [6,7,8,9,10,11,1,6]
plt.plot(x,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,80,19,40,1]
plt.scatter(x,y, c="r")
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,80,19,40,1]
plt.scatter(x,y, marker=">", color='red')
plt.show()

# %%
data = [1,2,3,4,5,1,2,3,6,7,8,1,2,3, 10,4,15,5,9,8]

# %% [markdown]
# The function plt.hist() in Matplotlib is used to create a histogram, which shows the distribution of numerical data.
#
# What is a Histogram?
# A histogram divides the range of values into intervals called bins.
#
# It then counts how many values fall into each bin and represents them as bars.
#
# Unlike a bar chart (which is for categorical data), a histogram is for continuous or numerical data.

# %%
plt.hist(data, edgecolor = "Red", color="black")
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,80,19,40,1]
colour = ['red','blue','#DFC010','#15CC10','green','yellow']
plt.scatter(x,y,c = colour)
plt.show()

# %% [markdown]
# Pie Chart
#
# What it is:
# A circle divided into slices, where each slice shows a percentage or fraction of the whole.
#
# When to use:
# To show proportions (e.g., "Market share of smartphone companies").

# %%
labels = ['Apple', 'Samsung', 'Xiaomi', 'Others']
sizes = [30, 25, 20, 25]
# explode = [0, 0, 0.1, 0.1]
plt.pie(sizes, labels=labels, autopct='%1.5f%%', startangle=90, explode = [0, 0, 0.2, 0.])
# Explode brings out a part out from the piechart
plt.title("Pie Chart")
plt.axis('equal')  # To make it a circle
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

# 3D FLow
# 1. Create a blank figure
# 2. Fig.add_subplot(projection='3d')

fig = plt.figure(figsize=(50,20)) # Creates a new blank figure (container for plots).
ax = fig.add_subplot(projection="3d") # Adds a 3D plotting area (subplot) to the figure.The argument projection='3d' is what makes this a 3D plot.
ax.scatter(x,y,z) # Creates a 3D scatter plot with the points (x, y, z).
ax.set_title('3D Line Plot Example')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
plt.legend(fontsize=100)
plt.show()

# Task -  Add a title for this plot, add x-axis, y-axis, and z-axis label also

# %% [markdown]
# Optional Parameters for legend()
#
# loc='upper right' → Position of legend.
#
# fontsize=10 → Font size of legend text.
#
# title='Legend' → Add a title to the legend.

# %%
z = np.linspace(0, 1, 100)
x = np.sin(z)
y = np.cos(z)

fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection='3d')
ax.scatter(x, y, z, color='green', label='sin-cos line')  # Add label
ax.set_title('3D Line Plot Example')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.legend(fontsize=20, loc='lower left', title="Legend of Line Graph")  # Smaller font

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Sample data
data = {
'Height': [150, 160, 170, 180, 190, 175, 165, 155],
'Weight': [50, 60, 65, 80, 90, 75, 62, 55],
'Age': [20, 21, 22, 23, 24, 25, 26, 27]
}
# Create DataFrame
df = pd. DataFrame(data)
print(df)
plt.figure(figsize=(8,6))
plt.scatter (df[ 'Height'], df[ 'Weight'],s=50, color='blue', marker='o')
plt.show()

# Task:
# Turn it to 3d

fig = plt.figure(figsize=(25,25))
by = fig.add_subplot(projection='3d')
by.plot(df[ 'Height'],df[ 'Weight'],df['Age'])
by.set_title("Scatter Plot 3d")
by.set_xlabel("Height")
by.set_ylabel("Weight")
by.set_zlabel("Age")
plt.legend(fontsize=20, loc="lower left", labels=["Height","Weight","Age"], title="3d height vs wright vs age", title_fontsize=50)
plt.show()

# %%
data = {
'Height': [150, 160, 170, 180, 190, 175, 165, 155],
'Weight': [50, 60, 65, 80, 90, 75, 62, 55],
'Age': [20, 21, 22, 23, 24, 25, 26, 27]
}
df = pd.DataFrame(data)
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection='3d')
ax.plot(df['Height'], df['Weight'], df['Age'],  color='green', label="Height vs Weight vs Age")
ax.set_title('3D Line Plot Example')
ax.set_xlabel('Height')
ax.set_ylabel('Weight')
ax.set_zlabel('Age')
ax.legend(loc='upper right', fontsize="20")

plt.show()

# %% [markdown]
# Stack Plot
#
# What it is:
# A line plot where multiple datasets are stacked on top of each other.
# It shows how different categories contribute to the total over time.

# %% [markdown]
# days → x-axis values.
#
# sleeping, eating, working, playing → multiple datasets stacked on top of each other.
#
# labels → Names for each dataset (used in the legend).
#
# colors → Colors for each stack:
#
# 'm' = magenta (Sleep)
#
# 'c' = cyan (Eat)
#
# 'r' = red (Work)
#
# 'k' = black (Play)
#
# Syntax: plt.stackplot(x, y1, y2, y3, ...)
#
# x → values for the horizontal axis
#
# y1, y2, ... → each array represents a layer of the stack (vertical values stacked on top of each other)
#
# Optional: colors=..., labels=...

# %%
days = [1, 2, 3, 4, 5]
sleeping = [7, 8, 6, 11, 7]
eating = [2, 3, 4, 3, 2]
working = [7, 8, 7, 2, 2]
playing = [8, 5, 7, 8, 13]

plt.stackplot(days, sleeping, eating, working, playing,
              labels=['Sleep', 'Eat', 'Work', 'Play'],
              colors=['blue','c','r','black'])
plt.legend(loc='lower left')
plt.title('Stack Plot Example')
plt.xlabel('Days')
plt.ylabel('Hours')
plt.xticks(days)  # Set x-ticks to match the days
plt.show()

# %% [markdown]
# Box Plot (Whisker Plot)
#
# What it is:
# Shows the spread of data:
#
# The box shows the middle 50% of data (quartiles).
#
# The line inside the box is the median.
#
# Whiskers show the min and max values.
#
# Dots outside whiskers are outliers.

# %% [markdown]
# What Does a Box Plot Show?
#
# Median (Q2): The middle value of the dataset.
#
# Q1 (25th percentile): The value below which 25% of the data lies.
#
# Q3 (75th percentile): The value below which 75% of the data lies.
#
# Interquartile Range (IQR): Q3 - Q1, the "height" of the box.
#
# Whiskers: Extend to the smallest and largest values within 1.5 × IQR.
#
# Outliers: Data points beyond whiskers, shown as dots or circles.

# %%
data = [1,7, 8, 5, 6, 9, 12, 15, 14, 10,50]

plt.boxplot(data,
            notch=True, # creates a notched box
            vert=True, # If True, creates a Vertical Box else creates a horizontal Box
            patch_artist=True, # Box are filled with colors
            showmeans=True, # Shows the median bar pointer
            boxprops=dict(facecolor='lightyellow', color='blue'), # Determines which color is used by the boxes, faceyellow is for box color, color is for border
            medianprops=dict(color='red', linewidth=2), # SHows the median bar with color red and width 2 inches
            meanprops=dict(marker='D', markerfacecolor='green', markersize=7), # Shows the marker pointing to medianprops
            whiskerprops=dict(color='black', linewidth=1.5), # Defines the line from q1 to small value and q3 to large value
            capprops=dict(color='purple', linewidth=1.5), # Defines the external lines of the whister plot
            flierprops=dict(marker='o', color='orange', markersize=6) # Defines the marker of the outliers
           )

plt.title("Customized Box Plot")
plt.show()

# %% [markdown]
# Heatmaps
#
# What it is:
# A 2D representation of data where values are represented as colors.
#
# When to use:
# To visualize intensity or patterns in matrices.
#
# A heatmap is a visualization that uses colors to show relationships, patterns, and correlations in data, making complex numbers easy to understand at a glance.

# %%
import numpy as np
data = np.random.rand(5, 5) # Creates a 5x5 array of random floating-point numbers between 0 and 1.
plt.imshow(data, cmap='gray', interpolation='nearest') # lt.imshow() displays data as an image (2D array). cmap = hot, Reds, winter, Greys. interpolation = hanning, hamming, nearest, bicubic, quadric
# Colormap to map data values to colors. 'hot' goes from black → red → yellow → white (heat colors).
# How to render pixels between data points. 'nearest' means no smoothing, pixels are shown as blocks.
plt.colorbar()  # Add color scale
plt.title('Heatmap Example')
plt.show()

# %%
import matplotlib.pyplot as plt

# X-axis categories
quarters = ['Q1', 'Q2', 'Q3', 'Q4']

# Heights of bars for Product A
product_a = [20, 35, 30, 25]

# Heights of bars for Product B
product_b = [15, 25, 35, 30]

# Plot the first set of bars
plt.bar(
    quarters,          # X-axis categories
    product_a,         # Heights of bars
    label='Product A', # Label for legend
    color='skyblue',   # Bar color (optional)
    width=0.5,         # Width of bars (optional)
    edgecolor='black'  # Edge color of bars (optional)
)

# Plot the second set of bars stacked on top of Product A
plt.bar(
    quarters,
    product_b,
    bottom=product_a,   # Stack on top of product_a
    label='Product B',
    color='orange',
    width=0.5,
    edgecolor='black',
    alpha = 0.5
)

# Add title of the chart
plt.title("Quarterly Sales", fontsize=14)

# Label for Y-axis
plt.ylabel("Sales", fontsize=12)

# Display legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# | Attribute    | Description                                       |
# | ------------ | ------------------------------------------------- |
# | `x`          | X-axis positions or categories                    |
# | `height`     | Heights of the bars                               |
# | `width`      | Width of the bars (default: 0.8)                  |
# | `bottom`     | Y-value to start the bar from (used for stacking) |
# | `align`      | Alignment of bars: `'center'` or `'edge'`         |
# | `color`      | Fill color of bars                                |
# | `edgecolor`  | Color of bar edges                                |
# | `label`      | Label for legend                                  |
# | `hatch`      | Pattern filling (`'/', '\', 'x', 'o', etc.`)      |
# | `alpha`      | Transparency of bars (0 to 1)                     |
# | `tick_label` | Labels for the X-axis ticks                       |

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create 100 points evenly spaced between 0 and 2*pi (full circle)
theta = np.linspace(0, 2*np.pi, 100)

# Define the radius for each angle (r = sin(theta))
r = np.sin(theta)

# Create a polar plot
plt.polar(
    theta,  # Angles (in radians)
    r,      # Radius values corresponding to each angle
    color='red',      # Color of the line (optional)
    linestyle='-',     # Line style: '-', '--', '-.', ':' (optional)
    linewidth=2,       # Width of the line (optional)
    marker='o',        # Marker style for points (optional)
    markersize=4,      # Size of the markers (optional)
    label='r = sin(theta)'  # Label for legend (optional)
)

# Add a title to the plot
plt.title("Polar Plot", fontsize=14)

# Add legend if labels are provided
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# | Attribute         | Description                               |
# | ----------------- | ----------------------------------------- |
# | `theta`           | Angles in radians                         |
# | `r`               | Radius values corresponding to each angle |
# | `color`           | Line color                                |
# | `linestyle`       | Line style: `'-', '--', '-.', ':'`        |
# | `linewidth`       | Width of the line                         |
# | `marker`          | Marker style: `'o', '^', '*', 's', etc.`  |
# | `markersize`      | Size of markers                           |
# | `label`           | Label for legend                          |
# | `alpha`           | Transparency (0 to 1)                     |
# | `markerfacecolor` | Fill color of markers                     |
# | `markeredgecolor` | Edge color of markers                     |
