# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# {1,2,3,4,5}

# %% [markdown]
# {1, 2, 3, 4, 5, 100, 120}

# %% [markdown]
# Outliers impact the machine learning algorithms which decreases the performance and accuracy of algorithms.

# %% [markdown]
# Outlier is important to check diseases like cancer.

# %% [markdown]
# 5 Number Summary

# %% [markdown]
# - Minimum Value
# - Q1 - 25 percentile
# - Q2 - Median or 50 percentile
# - Q3 - 75 Percentile
# - Maximum Value

# %%
import numpy as np # import numpy library as alias 'np'

# %%
# create a list of numbers with some outliers
numbers = [45, 32, 24, 56, 75, 89, 54, 32, 89, 90, 87, 67, 54, 45, 98, 99, 67, 74, 1000, 1100]

# %%
np.percentile(numbers, 0)  # minimum value

# %%
np.percentile(numbers, 25) # calculate the 25th percentile

# %%
np.percentile(numbers, 50) # calculate the 50th percentile

# %%
np.median(numbers) # calculate the median

# %%
np.percentile(numbers, 75) # calculate the 75th percentile

# %%
np.percentile(numbers, 100) # maximum value

# %% [markdown]
# Finding Outliers

# %%
import matplotlib.pyplot as plt
plt.boxplot(numbers)
plt.show()

# %% [markdown]
# [Lower Fence <--> Higher Fence]

# %%
minimum, Q1, median, Q3, maximum = np.quantile(numbers, [0, 0.25, 0.5, 0.75, 1]) # calculate the five number summary

# %%
minimum

# %%
Q1

# %%
median

# %%
Q3

# %%
maximum

# %%
iqr = Q3 - Q1
print(iqr)

# %%
lower_fence = Q1 - 1.5 * iqr
higher_fence = Q3 + 1.5 * iqr

# %%
lower_fence, higher_fence

# %%
numbers

# %%
outliers = []
for num in numbers:
    if num < lower_fence or num > higher_fence:
        outliers.append(num)

# %%
numbers

# %%
print(outliers)

# %%
import seaborn as sns

# %%
sns.boxplot(numbers)

# %%
numbers2 = [45, 32, 56, 75, 89, 54, 32, 89, 90, 87, 67, 54, 45, 98, 99, 67, 74]
numbers_array = np.array(numbers)
print(numbers_array)

# %%
sns.boxplot(numbers2)

# %%
lower_bound = numbers < lower_fence
upper_bound = numbers > higher_fence

print(np.any(upper_bound))

# %%
outliers = numbers_array[(numbers_array < lower_fence) | (numbers_array > higher_fence)]
print(outliers)

# %%
data = numbers_array[(numbers_array > lower_fence) & (numbers_array < higher_fence)]
data
